# %%
# %sql
create schema if not exists workspace.pj_sales;
create volume if not exists workspace.pj_sales.sales_resources;

# %%
# %fs
mkdirs /Volumes/workspace/pj_sales/sales_resources/origin/

# %%
# %fs
mkdirs /Volumes/workspace/pj_sales/sales_resources/processed/

# %%
resource_path    = '/Volumes/workspace/pj_sales/sales_resources/'
processed_path   = '/Volumes/workspace/pj_sales/sales_processed/'

# %% [markdown]
# #####Caso seja necessário testar a pipeline desde o início execute os códigos abaixo

# %%
# %skip
# %fs
mv /Volumes/workspace/pj_sales/sales_resources/processed/vendas_pecas_automotiva.csv /Volumes/workspace/pj_sales/sales_resources/origin/vendas_pecas_automotiva.csv

# %%
# %skip
# %sql
drop schema pj_sales cascade
